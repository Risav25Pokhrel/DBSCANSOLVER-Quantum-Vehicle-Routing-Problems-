# %%
import matplotlib.pyplot as plt
from dbscan_solver import DbScanSolver

# %%
dbSolver=DbScanSolver(path="In/c107.txt")
# Out:
# CSV file 'dataset1.csv' created successfully.
# Data set Loaded

# %%
df=dbSolver.applyRecursiveDBScan(min_radius=10,max_radius=165,min_no_clusters=3)
# Out:
# Vehicle Capacity: 200
# Radius range: [10.000, 165.000], min_clusters: 3
#
# Radius 87.500: 1 clusters, 0 noise points
# reducing max_radius to 86.500
#
# Radius 48.250: 1 clusters, 0 noise points
# reducing max_radius to 47.250
#
# Radius 28.625: 1 clusters, 0 noise points
# reducing max_radius to 27.625
#
# Radius 18.812: 2 clusters, 0 noise points
# reducing max_radius to 17.812
#
# Radius 13.906: 7 clusters, 0 noise points
#
# New best: 7 clusters, avg size 14.3
#
# Radius 16.359: 2 clusters, 0 noise points
# reducing max_radius to 15.359
#
# Radius 15.133: 3 clusters, 0 noise points
#
# New best: 3 clusters, avg size 33.3
# Best clustering: radius 15.133, 3 clusters
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Cluster 1: 83 points, demand 1460
#
# Capacity exceeded (1460 > 200)
# ################...recursing...########################
# Radius range: [8.000, 13.620], min_clusters: 2
#
# Radius 10.810: 7 clusters, 0 noise points
#
# ...

# %%
plt.figure(figsize=(14, 10))
plt.scatter(df.XCOORD, df.YCOORD, s=40, c=df.cluster, cmap="tab10")
plt.colorbar()
plt.show()
