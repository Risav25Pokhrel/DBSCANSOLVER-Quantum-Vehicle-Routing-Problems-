# %%
import matplotlib.pyplot as plt
from dbscan_solver import DbScanSolver

# %%
dbSolver=DbScanSolver(path="In/c101.txt")
# Out:
# CSV file 'dataset1.csv' created successfully.
# Data set Loaded

# %%
df=dbSolver.applyRecursiveDBScan(min_radius=10,max_radius=45,min_no_clusters=5)
# Out:
# Radius range: [10.000, 45.000], min_clusters: 5
#
# Radius 27.500: 1 clusters, 0 noise points
# reducing max_radius to 26.500
#
# Radius 18.250: 2 clusters, 0 noise points
# reducing max_radius to 17.250
#
# Radius 13.625: 6 clusters, 0 noise points
#
# New best: 6 clusters, avg size 16.8
#
# Radius 15.938: 2 clusters, 0 noise points
# reducing max_radius to 14.938
#
# Radius 14.781: 4 clusters, 0 noise points
# reducing max_radius to 13.781
# Best clustering: radius 13.625, 6 clusters
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Cluster 1: 57 points, demand 910
#
# Capacity exceeded (910 > 200)
# ################...recursing...########################
# Radius range: [8.000, 12.263], min_clusters: 2
#
# Radius 10.131: 4 clusters, 0 noise points
#
# New best: 4 clusters, avg size 14.2
#
# Radius 11.697: 4 clusters, 0 noise points
# Best clustering: radius 10.131, 4 clusters
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ...

# %%
plt.scatter(df.XCOORD, df.YCOORD, s=10, c=df.cluster, cmap="tab10")
plt.colorbar()
plt.show()
