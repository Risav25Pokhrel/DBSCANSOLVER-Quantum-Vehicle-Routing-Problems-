# %%
import matplotlib.pyplot as plt
from dbscan_solver import DbScanSolver

# %%
dbSolver=DbScanSolver(path="In/c101.txt")
# Out:
# CSV file 'dataset1.csv' created successfully.
# Data set Loaded

# %%
df=dbSolver.dbScan(min_radius=10,max_radius=45,max_cluster_size_const=22)
# Out:
# Radius: 27.500, Max cluster size: 100, Num clusters: 1
# Max cluster size 100 exceeds limit 22, reducing max_radius to 26.5
# Radius: 18.250, Max cluster size: 91, Num clusters: 2
# Max cluster size 91 exceeds limit 22, reducing max_radius to 17.25
# Radius: 13.625, Max cluster size: 32, Num clusters: 7
# Max cluster size 32 exceeds limit 22, reducing max_radius to 12.625
# Radius: 11.312, Max cluster size: 24, Num clusters: 9
# Max cluster size 24 exceeds limit 22, reducing max_radius to 10.3125
# Radius: 10.156, Max cluster size: 24, Num clusters: 9
# Max cluster size 24 exceeds limit 22, reducing max_radius to 9.15625
# No Solution Found...
# Searched radius range: [10.000, 45.000]
# Final radius: 10.156
# Try adjusting parameters: increase max_cluster_size_const or adjust radius range

# %%
df=dbSolver.dbScan(min_radius=10,max_radius=45,max_cluster_size_const=24)
# Out:
# Radius: 27.500, Max cluster size: 100, Num clusters: 1
# Max cluster size 100 exceeds limit 24, reducing max_radius to 26.5
# Radius: 18.250, Max cluster size: 91, Num clusters: 2
# Max cluster size 91 exceeds limit 24, reducing max_radius to 17.25
# Radius: 13.625, Max cluster size: 32, Num clusters: 7
# Max cluster size 32 exceeds limit 24, reducing max_radius to 12.625
# Radius: 11.312, Max cluster size: 24, Num clusters: 9
#
# New best solution: radius 11.312, avg cluster size 11.11
# Valid clustering found, increasing min_radius to 12.3125
#
# Radius: 12.469, Max cluster size: 24, Num clusters: 9
# Valid clustering found, increasing min_radius to 13.46875
#
#
# ~~~~~~~~~~~Cluster Formed~~~~~~~~~~~
#
# Best radius: 11.312 with average cluster size: 11
#
# Checking Capacity Constraints, vehicle capacity: 200
#
# Cluster 1 - Size: 12, Demand: 180, Status: OK , Utilization: 90.0
# Cluster 2 - Size: 8, Demand: 190, Status: OK , Utilization: 95.0
# ...

# %%
df=dbSolver.dbScan(min_radius=8,max_radius=45,max_cluster_size_const=20)
# Out:
# Radius: 26.500, Max cluster size: 100, Num clusters: 1
# Max cluster size 100 exceeds limit 20, reducing max_radius to 25.5
# Radius: 16.750, Max cluster size: 91, Num clusters: 2
# Max cluster size 91 exceeds limit 20, reducing max_radius to 15.75
# Radius: 11.875, Max cluster size: 24, Num clusters: 9
# Max cluster size 24 exceeds limit 20, reducing max_radius to 10.875
# Radius: 9.438, Max cluster size: 13, Num clusters: 10
#
# New best solution: radius 9.438, avg cluster size 10.00
# Valid clustering found, increasing min_radius to 10.4375
#
# Radius: 10.656, Max cluster size: 24, Num clusters: 9
# Max cluster size 24 exceeds limit 20, reducing max_radius to 9.65625
#
# ~~~~~~~~~~~Cluster Formed~~~~~~~~~~~
#
# Best radius: 9.438 with average cluster size: 10
#
# Checking Capacity Constraints, vehicle capacity: 200
#
# Cluster 1 - Size: 12, Demand: 180, Status: OK , Utilization: 90.0
# Cluster 2 - Size: 8, Demand: 190, Status: OK , Utilization: 95.0
# ...

# %%
plt.figure(figsize=(14, 10))
plt.scatter(df.XCOORD, df.YCOORD, s=15, c=df.cluster, cmap="tab10")
plt.colorbar()
plt.show()
